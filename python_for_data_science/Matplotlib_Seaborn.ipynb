# %% [markdown]
# ## matplotlib

# %% [markdown]
# Kategorik değişken: sütun grafik. countplot bar
#
# Sayısal değişken: hist, boxplot (kutu)
#
# Kategorik değişken : sütun grafik. countplot
#
# sayısal değişken : hist, boxplot
#
# kategorik degiskenleri gorsellestirme
#
# Kategorik degiskenler sütun grafik ile gosterilir
#
# matplotlib de barplot() metodu kullanilir
#
# seaborn da ise countplot() metodu kullanilir
#
# kütüphaneleri import etme ve veri setini okuma

# %%
# kütüphaneler
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Kategorik Değişken Görselleştirme

# %%
pd.set_option('display.max_columns', None)
# sağ tarafa doğru daha fazla değişken göremek için yapıyoruz
pd.set_option('display.width', 500)
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class    who  adult_male deck  embark_town alive  alone
# 0         0       3    male  22.0      1      0   7.2500        S  Third    man        True  NaN  Southampton    no  False
# 1         1       1  female  38.0      1      0  71.2833        C  First  woman       False    C    Cherbourg   yes  False
# 2         1       3  female  26.0      0      0   7.9250        S  Third  woman       False  NaN  Southampton   yes   True
# 3         1       1  female  35.0      1      0  53.1000        S  First  woman       False    C  Southampton   yes  False
# 4         0       3    male  35.0      0      0   8.0500        S  Third    man        True  NaN  Southampton    no   True

# %%
df['sex'].value_counts()
df['sex'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# # Sayısal Değişken Görselleştirme

# %% [markdown]
# sayisal degisknlerde veri goresllestirme ile elde edilecek olan sey, degiskenin dagilimi ve yapisidir.
#
# degiskenin dagilimini kolayca veren metotlar hist() ve boxplot() dur.
#
# boxplot() ayrica aykiri degerleri de gosterir
#
# matplotlib ile gorsellestirme
#
# histogram

# %%
# kütüphaneler
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 500)
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class    who  adult_male deck  embark_town alive  alone
# 0         0       3    male  22.0      1      0   7.2500        S  Third    man        True  NaN  Southampton    no  False
# 1         1       1  female  38.0      1      0  71.2833        C  First  woman       False    C    Cherbourg   yes  False
# 2         1       3  female  26.0      0      0   7.9250        S  Third  woman       False  NaN  Southampton   yes   True
# 3         1       1  female  35.0      1      0  53.1000        S  First  woman       False    C  Southampton   yes  False
# 4         0       3    male  35.0      0      0   8.0500        S  Third    man        True  NaN  Southampton    no   True

# %%
plt.hist(df["age"])
plt.show()

# %%
plt.hist(df['age'], bins=20)  # sayisal degiskenlerin dagilimi elde edilir
plt.show(block=True)
sns.histplot(df['age'])
plt.show(block=True)

# %% [markdown]
# kutu grafik (aykırı değerleri görelleştiryor)

# %%
# kutu grafik (aykırı değerleri görelleştiryor)
plt.boxplot(df["fare"])
plt.show()

# %% [markdown]
# # Matplotlib'in Özellikleri

# %%
# kütüphaneler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 500)

# %% [markdown]
# katmanlı bir yapıda

# %% [markdown]
# # plot

# %%
x = np.array([1, 8])
y = np.array([0, 150])

# %%
plt.plot(x, y)
plt.show()

# %%
plt.plot(x, y)
plt.plot(x, y, 'o')
plt.show()

# %% [markdown]
# bir çizgi değilde nokta oluşsun istersek

# %%
plt.plot(x, y, 'o')
plt.show()

# %%
x = np.array([2, 4, 6, 8, 10])
y = np.array([1, 3, 5, 7, 9])

# %%
plt.plot(x, y)
plt.show()

# %%
plt.plot(x, y)
plt.plot(x, y, 'o')
plt.show()

# %%
plt.plot(x, y, 'o')
plt.show()

# %% [markdown]
# # marker

# %%
y = np.array([13, 28, 11, 100])

# %%
plt.plot(y, marker='o')
plt.show()

# %%
plt.plot(y, marker='*')
plt.show()

# %% [markdown]
# diğer işaretler

# %%
markers = ['o', '*', '.', ',', 'x', 'X', '+', 'P', 's', 'D', 'd', 'p', 'H', 'h']

# %% [markdown]
# sadece çizgi

# %%
y = np.array([13, 28, 11, 100])
plt.plot(y, color="r")
plt.show()

# %% [markdown]
# kesikli çizgi mavi

# %%
y = np.array([13, 28, 11, 100])
plt.plot(y, linestyle="dashed", color="b")
plt.show()

# %% [markdown]
# noktalarla yeşil

# %%
y = np.array([13, 28, 11, 100])
plt.plot(y, linestyle="dotted", color="g")
plt.show()

# %% [markdown]
# hem çizgi hem nokta

# %%
y = np.array([13, 28, 11, 100])
plt.plot(y, linestyle="dashdot", color="r")
plt.show()

# %% [markdown]
# # Multiple Lines

# %%
x = np.array([23, 18, 31, 10])
y = np.array([13, 28, 11, 100])

# %%
plt.plot(x)
plt.plot(y)
plt.show()

# %%
plt.plot(x)

# %%
plt.plot(y)

# %% [markdown]
# # Labels (etiketler)

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x, y)
# Başlık
plt.title("Bu ana başlık")

# X eksenini isimlendirme
plt.xlabel("X ekseni isimlendirmesi")

plt.ylabel("Y ekseni isimlendirmesi")

plt.grid()
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x, y)

# %% [markdown]
# başlık ekleme

# %%
plt.title("Bu ana başlık")
# Out:
# Text(0.5, 1.0, 'Bu ana başlık')

# %% [markdown]
# X ekseni isimlendirmesi

# %%
# X eksenini isimlendirme
plt.xlabel("X ekseni isimlendirmesi")
# Out:
# Text(0.5, 0, 'X ekseni isimlendirmesi')

# %% [markdown]
# Y ekseni isimlendirmesi

# %%
plt.ylabel("Y ekseni isimlendirmesi")
# Out:
# Text(0, 0.5, 'Y ekseni isimlendirmesi')

# %% [markdown]
# ızgara ekleme

# %%
plt.grid()
plt.show()

# %% [markdown]
# # subplot

# %% [markdown]
# birden fazla görselin birlikte gösterilmesi

# %%
# plot 1
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.subplot(1, 2, 1)
plt.title("1")
plt.plot(x, y)

# plot 2
x = np.array([8, 8, 9, 9, 10, 15, 11, 15, 12, 15])
y = np.array([24, 20, 26, 27, 280, 29, 30, 30, 30, 30])
plt.subplot(1, 2, 2)
plt.title("2")
plt.plot(x, y)
plt.show()

# %% [markdown]
# 3 grafiği bir satır 3 sütun olarak konumlamak.

# %%
# 3 grafiği bir satır 3 sütun olarak konumlamak.
# plot 1
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.subplot(1, 3, 1)
plt.title("1")
plt.plot(x, y)

# plot 2
x = np.array([8, 8, 9, 9, 10, 15, 11, 15, 12, 15])
y = np.array([24, 20, 26, 27, 280, 29, 30, 30, 30, 30])
plt.subplot(1, 3, 2)
plt.title("2")
plt.plot(x, y)

# plot 3
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.subplot(1, 3, 3)
plt.title("3")
plt.plot(x, y)

plt.show()

# %% [markdown]
# # seaborn

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
df = sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df["sex"].value_counts()
sns.countplot(x=df["sex"], data=df)
plt.show()

# %%
df['sex'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# # Sayısal Değişken Görselleştirme

# %%
sns.boxplot(x=df["total_bill"])
plt.show()

# %%
df["total_bill"].hist()
plt.show()
